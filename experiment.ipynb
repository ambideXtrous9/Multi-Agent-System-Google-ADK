# %%
from ddgs import DDGS

# %%
query = "What is the meaning of life?"

# %%
results = DDGS().text(query, max_results=5)

# %%
type(results)
# Out:
# list

# %%
results
# Out:
# [{'title': 'What is the meaning of life?',
#   'href': 'https://en.wikipedia.org/wiki/What_is_the_meaning_of_life?',
# ...
